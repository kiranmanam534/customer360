# %%
base_adls2_path = "abfss://customer360unitycatalog@kmstorage9490.dfs.core.windows.net"

# %%
df = spark.readStream.format("cloudFiles") \
    .option("cloudFiles.format", "csv") \
    .option("cloudFiles.schemaLocation", f"{base_adls2_path}/schema/web_activities") \
    .option("cloudFiles.maxFilesPerTrigger", 10) \
    .load(f"{base_adls2_path}/raw/web_activities")

# %%
df.writeStream \
    .format("parquet") \
    .outputMode('append') \
    .option("checkpointLocation", f"{base_adls2_path}/checkpoints/web_activities") \
    .option("path", f"{base_adls2_path}/bronze/web_activities") \
    .trigger(once=True) \
    .toTable("customer360_cata.bronze.web_activities").awaitTermination()

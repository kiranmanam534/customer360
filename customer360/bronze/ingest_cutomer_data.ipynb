# %%
# %run /Workspace/Users/kiranmanam9490@outlook.com/customer360/common/config

# %%
customers_df = spark.read.format('csv')\
    .option('header','true')\
        .load('abfss://cusromer360@kmstorage9490.dfs.core.windows.net/source/customers')

# %%
bronze_path = "abfss://cusromer360@kmstorage9490.dfs.core.windows.net/bronze/customers"

customers_df.write.format("parquet") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .option("path", bronze_path) \
    .save()

# %%
# %run /Workspace/Users/kiranmanam9490@outlook.com/customer360/common/config

# %%
payments_df = spark.read.format('csv').option('header','true').load('abfss://cusromer360@kmstorage9490.dfs.core.windows.net/source/payments')

# %%
payments_df.write.format('parquet').mode('overwrite').save('abfss://cusromer360@kmstorage9490.dfs.core.windows.net/bronze/payments')

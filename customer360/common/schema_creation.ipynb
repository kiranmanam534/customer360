# %%
# %sql
DROP SCHEMA IF EXISTS customer360.bronze CASCADE;
DROP SCHEMA IF EXISTS customer360.silver CASCADE;
DROP SCHEMA IF EXISTS customer360.gold CASCADE;

# %%
# %sql
DROP CATALOG customer360 CASCADE;

# %%
# %sql
create catalog customer360

# %%
# %sql
USE CATALOG customer360

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze

# %%
# %sql
create schema if not exists silver

# %%
# %sql
create schema if not exists gold
